# %%
from vote_simulation.simulation.simulation import simulation_series_from_config

results = simulation_series_from_config("config.toml", reload=True, compute_metrics=True)
# Out:
# Running simulation series:   0%|          | 0/1 [00:00<?, ?it/s]
# Warning: unknown rule code 'AP_T0GE' — skipped.
# Running simulation series: 100%|██████████| 1/1 [00:12<00:00, 12.96s/it]
# Completed 1 simulation series.

# %%
import numpy as np
import pandas as pd

a = []
for _ in range(10000):
    a.append(np.random.randint(9))
series = pd.Series(a)
pd.value_counts(a)
# Out:
# /tmp/ipykernel_136905/731916050.py:8: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(a)
# /tmp/ipykernel_136905/731916050.py:8: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.value_counts(a)
# 3    1170
# 5    1122
# 6    1116
# 8    1107
# 2    1105
# 1    1104
# 0    1095
# 4    1094
# 7    1087
# Name: count, dtype: int64
