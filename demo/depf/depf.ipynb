# %% [markdown]
# # Depf function greedy vs exact

# %%
from vote_simulation.simulation.simulation import simulation_series_from_config

results = simulation_series_from_config("depf.toml", reload=False, compute_metrics=True)
# Out:
# Running simulation series:   0%|                        | 0/24 [00:00<?, ?it/s]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:   4%|▋               | 1/24 [00:01<00:32,  1.42s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:   8%|█▎              | 2/24 [00:02<00:32,  1.46s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  12%|██              | 3/24 [00:04<00:32,  1.53s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  17%|██▋             | 4/24 [00:06<00:32,  1.64s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  21%|███▎            | 5/24 [00:07<00:30,  1.58s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  25%|████            | 6/24 [00:09<00:28,  1.56s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  29%|████▋           | 7/24 [00:11<00:27,  1.62s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  33%|█████▎          | 8/24 [00:12<00:26,  1.66s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  38%|██████          | 9/24 [00:14<00:24,  1.63s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  42%|██████▎        | 10/24 [00:15<00:22,  1.61s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  46%|██████▉        | 11/24 [00:17<00:21,  1.64s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  50%|███████▌       | 12/24 [00:19<00:20,  1.67s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  54%|████████▏      | 13/24 [00:20<00:17,  1.63s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  58%|████████▊      | 14/24 [00:22<00:16,  1.61s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  62%|█████████▍     | 15/24 [00:24<00:14,  1.64s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  67%|██████████     | 16/24 [00:25<00:13,  1.65s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  71%|██████████▋    | 17/24 [00:27<00:11,  1.60s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  75%|███████████▎   | 18/24 [00:29<00:09,  1.63s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  79%|███████████▉   | 19/24 [00:30<00:08,  1.61s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  83%|████████████▌  | 20/24 [00:32<00:06,  1.61s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  88%|█████████████▏ | 21/24 [00:33<00:04,  1.57s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  92%|█████████████▊ | 22/24 [00:35<00:03,  1.62s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series:  96%|██████████████▍| 23/24 [00:37<00:01,  1.72s/it]
# Warning: unknown rule code 'MMAX' — skipped.
# Running simulation series: 100%|███████████████| 24/24 [00:40<00:00,  1.67s/it]
# Completed 24 simulation series.

# %%
results.filter(n_voters=100).plot_metric_heatmap(row_param="gen_model", col_param="n_candidates")

results.filter(n_voters=10).plot_metric_heatmap(row_param="gen_model", col_param="n_candidates")
# Out:
# <Axes: title={'center': 'Mean Distance\n(n_voters=10)'}, xlabel='n_candidates', ylabel='gen_model'>

# %%
df = results.summary_frame()
print(df.to_string(index=False))

results.plot_mean_distance_matrix()
# Out:
#      gen_model  n_voters  n_candidates  step_count  n_iterations  mean_distance most_distant_rule_a most_distant_rule_b  most_distant_distance
#       DDD_BETA        10             3         500           500       6.251852                PLU1                  RV              11.600000
#       DDD_BETA        10             5         500           500       8.976852                PLU1                  RV              15.866667
#       DDD_BETA        10             7         500           500      11.007870                PLU1                  RV              19.833334
#       DDD_BETA        10             8         500           500      12.494537                PLU1                  RV              22.426666
#       DDD_BETA       100             3         500           500       2.836111                BORD                PLU1               7.400000
#       DDD_BETA       100             5         500           500       4.658333                BORD                PLU1              10.500000
#       DDD_BETA       100             7         500           500       6.292592                PLU1                  RV              14.400000
#       DDD_BETA       100             8         500           500       7.282407                PLU1                  RV              15.800000
# DDD_BETA_POLAR        10             3         500           500      20.585185                PLU1                  RV              33.799999
# DDD_BETA_POLAR        10             5         500           500      30.430650                PLU1                  RV              53.326668
# DDD_BETA_POLAR        10             7         500           500      37.500278                PLU1                  RV              64.326668
# DDD_BETA_POLAR        10             8         500           500      40.680834                PLU1                  RV              69.283333
# DDD_BETA_POLAR       100             3         500           500      23.876851                BORD                PLU1              42.533333
# DDD_BETA_POLAR       100             5         500           500      35.828240                PLU1                  RV              67.900002
# DDD_BETA_POLAR       100             7         500           500      42.131944                PLU1                  RV              75.699997
# DDD_BETA_POLAR       100             8         500           500      47.102776                PLU1                  RV              82.500000
#            UNI        10             3         500           500      20.059258                  MJ                PLU1              35.000000
#            UNI        10             5         500           500      30.972131                  MJ                PLU1              51.153332
#            UNI        10             7         500           500      37.043057                  MJ                PLU1              56.520000
#            UNI        10             8         500           500      42.710832                PLU1                  RV              64.713333
#            UNI       100             3         500           500      19.023149                  MJ                PLU1              36.099998
#            UNI       100             5         500           500      33.442593                  MJ                PLU1              55.666668
#            UNI       100             7         500           500      38.765279                  MJ                PLU1              62.633335
#            UNI       100             8         500           500      43.933424                  MJ                PLU1              70.266670
# <Axes: title={'center': 'Mean rule distance matrix\n24 series averaged'}, xlabel='Rules', ylabel='Rules'>

# %%
# serie = results.get_series(n_candidates=8, gen_model="DDD_BETA_POLAR", n_voters=100)
#
# serie.plot_mean_distance_matrix()

gen_mod = ["DDD_BETA_POLAR", "DDD_BETA", "UNI"]

for g in gen_mod:
    serie = results.get_series(n_candidates=8, gen_model=g, n_voters=100)
    serie.plot_mean_distance_matrix()

# %% [markdown]
# Bon nanson est une bonne approximation de depth apparement.

# %%
results.plot_metrics_rules_matrix()
# Out:
# <Axes: title={'center': 'Winner metrics (mean) per rule\n24 series averaged'}, xlabel='Metric', ylabel='Rule'>
