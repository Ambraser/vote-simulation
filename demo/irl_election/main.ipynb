# %% [markdown]
# """
# This file run simulations on irl elections (folder data) using elements of the simulation workflow
#
# It apply the following rules :
#
# rule_codes = [
#     "AP_T05",
#     "AP_T07",
#     "AP_T0GE",
#     "BALD",
#     "BLAC",
#     "BORD",
#     "BUCK_I",
#     "BUCK_R",
#     "CAIR",
#     "COOM",
#     "COPE",
#     "HARE",
#     "KIMR",
#     "L4DV",
#     "L6DV",
#     "MJ",
#     "MMIN",
#     "NANS",
#     "PLU1",
#     "PLU2",
#     "RANDOM_DICTATOR",
#     "RANDOM_WINNER",
#     "RV",
#     "SCHU",
#     "STAR",
#     "VETO",
#     "WOOD",
#     "YOUN",
#     "AP_K2",
#     "AP_K3",
#     "AP_KRP",
#     "DODG_C",
#     "COND",
# ]
#
#
# """
